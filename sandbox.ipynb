# %%
from sqlite3 import connect

# %%
connection = connect("issue_tracker.db")

# %%
einkaufswagen = connection.execute("""
CREATE TABLE issue (
    issue_id INTEGER PRIMARY KEY AUTOINCREMENT,
    name TEXT,
    priority TEXT, 
    deadline DATETIME,
    is_done BOOL,
    description TEXT
);                               
""")

connection.commit(
)

# %%
einkaufswagen = connection.execute("""
insert into issue (name, description, deadline) values
('Einkaufen gegen', ' Kaufe Eier, Milch und Brot', ' 2026-04-22');                               
""")

connection.commit()

# %%
einkaufswagen = connection.execute("""
                                   select * from issue;
                                   """)

einkaufswagen.fetchall()
# Out:
# [(1,
#   'Einkaufen gegen',
#   None,
#   ' 2026-04-22',
#   None,
#   ' Kaufe Eier, Milch und Brot')]

# %%
def add_issue (name, description, deadline):
    connection = connect ("issue_tracker.db")
    sql = f"insert into issue (name, description, deadline, is done) values ('{name}', '{description}', '{deadline}');"
    einkaufswagen = connection.execute(sql)
    connection.commit()
    einkaufswagen.close ()
    connection.close()

# %%
add_issue("Blumen kaufen", "Kaufe einen Strauß Rosen für Mama", "2026-05-01")

# %%
einkaufswagen = connection.execute("""
                                   select * from issue;
                                   """)

einkaufswagen.fetchall()
# Out:
# [(1,
#   'Einkaufen gegen',
#   None,
#   ' 2026-04-22',
#   None,
#   ' Kaufe Eier, Milch und Brot'),
#  (2,
#   'Blumen kaufen',
#   None,
#   '2026-05-01',
#   None,
#   'Kaufe einen Strauß Rosen für Mama')]

# %%
def get_issues():
    connection = connect ("issue_tracker.db")
    sql = "select * from issue where is_done = 0;"
    einkaufswagen = connection.execute(sql)
    data = einkaufswagen.fetchall()
    einkaufswagen.close ()
    connection.close()
    return data

# %%
get_issues()
# Out:
# [(1,
#   'Einkaufen gegen',
#   None,
#   ' 2026-04-22',
#   None,
#   ' Kaufe Eier, Milch und Brot'),
#  (2,
#   'Blumen kaufen',
#   None,
#   '2026-05-01',
#   None,
#   'Kaufe einen Strauß Rosen für Mama')]

# %%
get_issues()
# Out:
# []
